# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import urllib.request
from konlpy.tag import Okt
from tqdm import tqdm
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pickle

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt", filename="ratings_train.txt")
# Out:
# ('ratings_train.txt', <http.client.HTTPMessage at 0x1236cb87e20>)

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt", filename="ratings_test.txt")
# Out:
# ('ratings_test.txt', <http.client.HTTPMessage at 0x1236cb87af0>)

# %%
train_data=pd.read_table('ratings_train.txt')
test_data=pd.read_table('ratings_test.txt')

# %%
print('훈련용 리뷰 개수 :',len(train_data))
# Out:
# 훈련용 리뷰 개수 : 150000

# %%
train_data[:5]
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
test_data[:5]
# Out:
#         id                                           document  label
# 0  6270596                                                굳 ㅋ      1
# 1  9274899                               GDNTOPCLASSINTHECLUB      0
# 2  8544678             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3  6825595                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4  6723715  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0

# %%
train_data['document'].nunique(),train_data['label'].nunique()
# Out:
# (146182, 2)

# %%
train_data.drop_duplicates(subset=['document'],inplace=True)

# %%
print(len(train_data))
# Out:
# 146183

# %%
train_data=train_data.dropna(how='any')
print(train_data.isnull().values.any())
# Out:
# False

# %%
train_data['document']=train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ0-9가-힣]","",regex=True)

# %%
train_data[:5]
# Out:
#          id                                           document  label
# 0   9976970                                      아더빙진짜짜증나네요목소리      0
# 1   3819312                            흠포스터보고초딩영화줄오버연기조차가볍지않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                               교도소이야기구먼솔직히재미는없다평점조정      0
# 4   6483659  사이몬페그의익살스런연기가돋보였던영화스파이더맨에서늙어보이기만했던커스틴던스트가너무나도이...      1

# %%
train_data['document']=train_data['document'].str.replace('^ +',"",regex=True)
train_data['document'].replace('', np.nan, inplace=True)
print(train_data.isnull().sum())
# Out:
# id            0
# document    685
# label         0
# dtype: int64

# %%
train_data = train_data.dropna(how = 'any')
print(len(train_data))
# Out:
# 145497

# %%
test_data.drop_duplicates(subset = ['document'], inplace=True) # document 열에서 중복인 내용이 있다면 중복 제거
test_data['document'] = test_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","",regex=True) # 정규 표현식 수행
test_data['document'] = test_data['document'].str.replace('^ +', "",regex=True) # 공백은 empty 값으로 변경
test_data['document'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
test_data = test_data.dropna(how='any') # Null 값 제거
print('전처리 후 테스트용 샘플의 개수 :',len(test_data))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 48852

# %%
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
okt=Okt()
X_train = []
for sentence in tqdm(train_data['document']):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_train.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 145497/145497 [1:15:25<00:00, 32.15it/s]

# %%
print(X_train[:3])
# Out:
# [['아더', '빙', '진짜', '짜증나다', '목소리'], ['흠', '포스터', '보고', '초딩', '영화', '줄', '오버', '연기', '조차', '가볍다', '않다'], ['너', '무재', '밓었', '다그', '래서', '보다', '추천', '다']]

# %%
X_test = []
for sentence in tqdm(test_data['document']):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    X_test.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 48852/48852 [04:51<00:00, 167.47it/s]

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
print(tokenizer.word_index)
# Out:
# {'영화': 1, '보다': 2, '을': 3, '없다': 4, '이다': 5, '좋다': 6, '다': 7, '너무': 8, '하': 9, '정말': 10, '재밌다': 11, '적': 12, '되다': 13, '같다': 14, '있다': 15, '진짜': 16, '만': 17, '않다': 18, '로': 19, '점': 20, '아니다': 21, '에서': 22, '내': 23, '평점': 24, '그': 25, '최고': 26, '인': 27, '나': 28, '연기': 29, '생각': 30, '스토리': 31, '게': 32, '이영화': 33, '감동': 34, '드라마': 35, '사람': 36, '1': 37, '만들다': 38, '고': 39, '요': 40, 'ㅋㅋ': 41, '나오다': 42, '이런': 43, '아깝다': 44, '왜': 45, '재미있다': 46, '배우': 47, '지': 48, '보고': 49, '감독': 50, '네': 51, '때': 52, '그냥': 53, '하고': 54, '들다': 55, '아': 56, '재미없다': 57, '가다': 58, '중': 59, '뭐': 60
심': 284, '실망': 285, '보이다': 286, '몰입': 287, '계속': 288, '알': 289, 'ㅎ': 290, '이지': 291, '극': 292, '떨어지다': 293, '이상': 294, '가장': 295, '믿다': 296, '모두': 297, '웃다': 298, '잔잔하다': 299, '전혀': 300, '보지': 301, '대단하다': 302, '그런': 303, '일본': 304, '개봉': 305, '요즘': 306, '스릴러': 307, '긴장감': 308, '작가': 309, '점도': 310, '가보다': 311, '위': 312, '해보다': 313, '용도': 314, '잼': 315, '서다': 316, '잇다': 317, '특히': 318, '기분': 319, '이라는': 320, '빠지다': 321, '지다': 322, '식': 323, '한테': 324, '4': 325, '개인': 326, '0': 327, '공포': 328, '알바': 329, '상': 330, '점수': 331, '극장': 332, '애니': 333, '노잼': 334, '나름': 335, '예쁘다': 336, '용': 337, '력': 338, '노래': 339, '이상하다': 340, '삶': 341, '시작': 342, '공포영화': 343, '깊다': 344, '조금': 345, '필요없다': 346, '의미': 347, '명': 348, '류': 349, '이란': 350, '그리다': 351, '용이': 352, '어설프다': 353, '위해': 354, '데': 355, '웃음': 356, '차라리': 357, '따다': 358, '놈': 359, '아주': 360, '딱': 361, '따뜻하다': 362, '친구': 363, '느껴지다': 364, '막장': 365, '에도': 366, '굿': 367, '훌륭하다': 368, '한국영': 369, '감': 370, '빼다': 371, '점주': 372, '죽이다': 373, '아무': 374,  ...

# %%
threshold=3
total_cnt=len(tokenizer.word_index)
rare_cnt=0
total_freq=0
rare_freq=0

for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 52404
# 등장 빈도가 2번 이하인 희귀 단어의 수: 31368
# 단어 집합에서 희귀 단어의 비율: 59.858026104877496
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 2.3882671953963817

# %%
vocab_size=total_cnt-rare_cnt+1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 21037

# %%
tokenizer=Tokenizer(vocab_size)
tokenizer.fit_on_texts(X_train)
X_train=tokenizer.texts_to_sequences(X_train)
X_test=tokenizer.texts_to_sequences(X_test)

# %%
print(X_train[:3])
# Out:
# [[9810, 11394, 16, 247, 662], [1082, 467, 49, 613, 1, 453, 1526, 29, 1087, 672, 18], [212, 1753, 598, 3654, 2, 229, 7]]

# %%
y_train = np.array(train_data['label'])
y_test = np.array(test_data['label'])

# %%
drop_train = [index for index, sentence in enumerate(X_train) if len(sentence) < 1]

# %%
X_train = np.delete(X_train, drop_train, axis=0)
y_train = np.delete(y_train, drop_train, axis=0)
print(len(X_train))
print(len(y_train))
# Out:
# 145087
# 145087
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:4454: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asarray(arr)

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 68
# 리뷰의 평균 길이 : 10.559615954565192

# %%
def below_threshold_len(max_len, nested_list):
  count = 0
  for sentence in nested_list:
    if(len(sentence) <= max_len):
        count = count + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (count / len(nested_list))*100))

# %%
max_len = 30
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 30 이하인 샘플의 비율: 94.73488320800622

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding, Dropout, Conv1D, GlobalMaxPooling1D, Dense, Input, Flatten, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model

# %%
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
embedding_dim = 128
dropout_ratio = (0.5, 0.8)
num_filters = 128
hidden_units = 128

# %%
model_input = Input(shape = (max_len,))
z = Embedding(vocab_size, embedding_dim, input_length = max_len, name="embedding")(model_input)
z = Dropout(dropout_ratio[0])(z)

# %%
conv_blocks = []

for sz in [3, 4, 5]:
    conv = Conv1D(filters = num_filters,
                         kernel_size = sz,
                         padding = "valid",
                         activation = "relu",
                         strides = 1)(z)
    conv = GlobalMaxPooling1D()(conv)
    conv_blocks.append(conv)

# %%
z = Concatenate()(conv_blocks) if len(conv_blocks) > 1 else conv_blocks[0]
z = Dropout(dropout_ratio[1])(z)
z = Dense(hidden_units, activation="relu")(z)
model_output = Dense(1, activation="sigmoid")(z)

model = Model(model_input, model_output)
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["acc"])

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('C:/Users/tpgus/fasttext_api/data/mecab/cnn_model2', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.fit(X_train, y_train, batch_size=64, epochs=10, validation_split=0.2, verbose=2, callbacks=[es, mc])
# Out:
# Epoch 1/10
#
# Epoch 1: val_acc improved from -inf to 0.83683, saving model to C:/Users/tpgus/fasttext_api/data/mecab\cnn_model2
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/tpgus/fasttext_api/data/mecab\cnn_model2\assets
# INFO:tensorflow:Assets written to: C:/Users/tpgus/fasttext_api/data/mecab\cnn_model2\assets
# 1814/1814 - 59s - loss: 0.4430 - acc: 0.7846 - val_loss: 0.3761 - val_acc: 0.8368 - 59s/epoch - 32ms/step
# Epoch 2/10
#
# Epoch 2: val_acc improved from 0.83683 to 0.84155, saving model to C:/Users/tpgus/fasttext_api/data/mecab\cnn_model2
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/tpgus/fasttext_api/data/mecab\cnn_model2\assets
# INFO:tensorflow:Assets written to: C:/Users/tpgus/fasttext_api/data/mecab\cnn_model2\assets
# 1814/1814 - 60s - loss: 0.3505 - acc: 0.8492 - val_loss: 0.3641 - val_acc: 0.8415 - 60s/epoch - 33ms/step
# Epoch 3/10
#
# Epoch 3: val_acc improved from 0.84155 to 0.84182, saving model to C:/Users/tpgus/fasttext_api/data/mecab\cnn_model2
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:/Users/tpgus/fasttext_api/data/mecab\cnn_model2\assets
# INFO:tensorflow:Assets written to: C:/Users/tpgus/fasttext_api/data/mecab\cnn_model2\assets
# 1814/1814 - 54s - loss: 0.3166 - acc: 0.8669 - val_loss: 0.3623 - val_acc: 0.8418 - 54s/epoch - 30ms/step
# Epoch 4/10
#
# Epoch 4: val_acc did not improve from 0.84182
# 1814/1814 - 54s - loss: 0.2878 - acc: 0.8800 - val_loss: 0.3641 - val_acc: 0.8405 - 54s/epoch - 30ms/step
# Epoch 5/10
#
# Epoch 5: val_acc did not improve from 0.84182
# 1814/1814 - 61s - loss: 0.2657 - acc: 0.8907 - val_loss: 0.3725 - val_acc: 0.8384 - 61s/epoch - 34ms/step
# Epoch 6/10
#
# Epoch 6: val_acc did not improve from 0.84182
# 1814/1814 - 59s - loss: 0.2483 - acc: 0.8984 - val_loss: 0.3790 - val_acc: 0.8379 - 59s/epoch - 33ms/step
# Epoch 7/10
#
# Epoch 7: val_acc did not improve from 0.84182
# 1814/1814 - 57s - loss: 0.2312 - acc: 0.9059 - val_loss: 0.3976 - val_acc: 0.8349 - 57s/epoch - 31ms/step
# Epoch 7: early stopping

# %%
loaded_model = load_model('C:/Users/tpgus/fasttext_api/data/mecab/cnn_model2')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 1527/1527 [==============================] - 4s 3ms/step - loss: 0.3667 - acc: 0.8392
#
#  테스트 정확도: 0.8392

# %%
def sentiment_predict(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정 리뷰입니다.\n".format((1 - score) * 100))

# %%
sentiment_predict('그게 정말인가요?')
# Out:
# 1/1 [==============================] - 0s 12ms/step
# 94.09% 확률로 부정 리뷰입니다.

# %%
with open('C:/Users/tpgus/fasttext_api/data/mecab/tokenizer2.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle)
